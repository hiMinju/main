# %% [markdown]
# #  2017203028 김민주
#
# ## 한식 사진 웹 브라우저에서 자동 추출

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome(r'C:\Users\minju\Anaconda3\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.google.com')

# %%
search_term = 'korean+food'
counter = 0
succounter = 0

url = "http://www.google.com/search?q="+search_term+"&source=lnms&tbm=isch"
browser = webdriver.Chrome(r'C:\Users\minju\Anaconda3\chromedriver_win32\chromedriver.exe')
driver.implicitly_wait(5)

browser.get(url)
    
for _ in range(200):
    browser.execute_script("window.scrollBy(0,10000)")
    
#for idx, el in enumerate(browser.find_elements_by_class_name("rg_ic")):
#    el.screenshot(str(idx) + ".png")
for x in browser.find_elements_by_xpath('//div[contains(@class,"rg_meta")]'):
    counter = counter + 1
    

browser.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-24-0930d52a7bd3> in <module>
#      11
#      12 for idx, el in enumerate(browser.find_elements_by_class_name("rg_ic")):
# ---> 13     el.screenshot(str(idx) + ".png")
#      14
#      15 browser.close()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in screenshot(self, filename)
#     583             warnings.warn("name used for saved screenshot does not match file "
#     584                           "type. It should end with a `.png` extension", UserWarning)
# --> 585         png = self.screenshot_as_png
#     586         try:
#     587             with open(filename, 'wb') as f:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in screenshot_as_png(self)
#     565             element_png = element.screenshot_as_png
#     566         """
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import json
import os
import urllib.request

searchterm = 'korean+food'
url = "https://www.google.com/search?q="+searchterm+"&source=lnms&tbm=isch"
browser = webdriver.Chrome(r'C:\Users\minju\Anaconda3\chromedriver_win32\chromedriver.exe')
    
first_list = ['korean', '한국']
second_list = ['food', '음식', '음식사진']

try:
    os.makedirs('./screenshots')
except OSError:
    pass
os.chdir('./screenshots')

for first in first_list:
    for second in second_list:
        url = "https://www.google.com/search?q="+new_query+"&source=lnms&tbm=isch"
        new_query = first + " " + second
        browser.get(url)
        
        for i in range(50):
            browser.execute_script('window.scrollBy(0,10000)')
            
        for idx, el in enumerate(browser.find_elements_by_xpath("//img[@class='rg_ic']")):
            el.screenshot(str(idx) + ".png")
            
    browser.close()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-62-7ac3c4cb1552> in <module>
#      22         url = "https://www.google.com/search?q="+new_query+"&source=lnms&tbm=isch"
#      23         new_query = first + " " + second
# ---> 24         browser.get(url)
#      25
#      26         for i in range(50):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
# ...

# %%
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
# 이미지 카운트 (이미지 저장할 때 사용하기 위해서)
counter = 0
succounter = 0
 
print(os.path)
# 소스코드가 있는 경로에 '검색어' 폴더가 없으면 만들어준다.(이미지 저장 폴더를 위해서) 
if not os.path.exists(searchterm):
    os.mkdir(searchterm)
 
for _ in range(500):
    # 가로 = 0, 세로 = 10000 픽셀 스크롤한다.
    browser.execute_script("window.scrollBy(0,10000)")

    for x in browser.find_elements_by_xpath('//div[contains(@class,"rg_meta")]'):
        counter = counter + 1
        print ("Total Count:", counter)
        print ("Succsessful Count:", succounter)
        print ("URL:",json.loads(x.get_attribute('innerHTML'))["ou"])
 
    # 이미지 url
    img = json.loads(x.get_attribute('innerHTML'))["ou"]
    # 이미지 확장자
    imgtype = json.loads(x.get_attribute('innerHTML'))["ity"]
    
    # 구글 이미지를 읽고 저장한다.
    try:
        req = urllib.request(img, headers={'User-Agent': header})
        raw_img = urllib.request.urlopen(req).read()
        File = open(os.path.join(searchterm , searchterm + "_" + str(counter) + "." + imgtype), "wb")
        File.write(raw_img)
        File.close()
        succounter = succounter + 1
    except:
            print ("can't get img")
            
print (succounter, "succesfully downloaded")
browser.close()
# Out:
# <module 'ntpath' from 'C:\\Users\\minju\\Anaconda3\\lib\\ntpath.py'>
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-31-70e171cfc0e6> in <module>
#      11 for _ in range(500):
#      12     # 가로 = 0, 세로 = 10000 픽셀 스크롤한다.
# ---> 13     browser.execute_script("window.scrollBy(0,10000)")
#      14
#      15     for x in browser.find_elements_by_xpath('//div[contains(@class,"rg_meta")]'):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
for x in browser.find_elements_by_xpath('//div[contains(@class,"rg_meta")]'):
    counter = counter + 1
    print ("Total Count:", counter)
    print ("Succsessful Count:", succounter)
    print ("URL:",json.loads(x.get_attribute('innerHTML'))["ou"])
 
    # 이미지 url
    img = json.loads(x.get_attribute('innerHTML'))["ou"]
    # 이미지 확장자
    imgtype = json.loads(x.get_attribute('innerHTML'))["ity"]
    
    # 구글 이미지를 읽고 저장한다.
    try:
        req = urllib.request(img, headers={'User-Agent': header})
        raw_img = urllib.request.urlopen(req).read()
        File = open(os.path.join(searchterm , searchterm + "_" + str(counter) + "." + imgtype), "wb")
        File.write(raw_img)
        File.close()
        succounter = succounter + 1
    except:
            print ("can't get img")
            
print (succounter, "succesfully downloaded")
browser.close()
# Out:
#   File "<ipython-input-29-33167b3403cc>", line 13
#     req = urllib.request(img, headers={'User-Agent': header})
#     ^
# IndentationError: unexpected indent

# %%
# User-Agent를 통해 봇이 아닌 유저정보라는 것을 위해 사용
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
# 이미지 카운트 (이미지 저장할 때 사용하기 위해서)
counter = 0
succounter = 0
 
print(os.path)
# 소스코드가 있는 경로에 '검색어' 폴더가 없으면 만들어준다.(이미지 저장 폴더를 위해서) 
if not os.path.exists(searchterm):
    os.mkdir(searchterm)
 
for _ in range(500):
    # 가로 = 0, 세로 = 10000 픽셀 스크롤한다.
    browser.execute_script("window.scrollBy(0,10000)")
# Out:
# <module 'ntpath' from 'C:\\Users\\minju\\Anaconda3\\lib\\ntpath.py'>
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-32-95f85dce3089> in <module>
#      12 for _ in range(500):
#      13     # 가로 = 0, 세로 = 10000 픽셀 스크롤한다.
# ---> 14     browser.execute_script("window.scrollBy(0,10000)")
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import json
import os
import urllib.request

searchterm = 'korean+food'
url = "https://www.google.com/search?q="+searchterm+"&source=lnms&tbm=isch"
browser = webdriver.Chrome(r'C:\Users\minju\Anaconda3\chromedriver_win32\chromedriver.exe')
browser.get(url)

# User-Agent를 통해 봇이 아닌 유저정보라는 것을 위해 사용
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
# 이미지 카운트 (이미지 저장할 때 사용하기 위해서)
counter = 0
succounter = 0
 
print(os.path)
# 소스코드가 있는 경로에 '검색어' 폴더가 없으면 만들어준다.(이미지 저장 폴더를 위해서) 
if not os.path.exists(searchterm):
    os.mkdir(searchterm)
 
for _ in range(100):
    # 가로 = 0, 세로 = 10000 픽셀 스크롤한다.
    browser.execute_script("window.scrollBy(0,10000)")

# div태그에서 class name이 rg_meta인 것을 찾아온다
for x in browser.find_elements_by_xpath('//div[contains(@class,"rg_meta")]'):
    counter = counter + 1
    print ("Total Count:", counter)
    print ("Succsessful Count:", succounter)
    print ("URL:",json.loads(x.get_attribute('innerHTML'))["ou"])
 
    # 이미지 url
    img = json.loads(x.get_attribute('innerHTML'))["ou"]
    # 이미지 확장자
    imgtype = json.loads(x.get_attribute('innerHTML'))["ity"]
    
    # 구글 이미지를 읽고 저장한다.
    for idx, el in enumerate(browser.find_elements_by_class_name("rg_ic")):
        response = requests.get(url, stream=True)
        
        
    req = urllib.request(img, headers={'User-Agent': header})
    raw_img = urllib.request.urlopen(req).read()
    File = open(os.path.join("koreanFood" , "koreanFood_" + str(counter) + "." + imgtype), "wb")
    File.write(raw_img)
    File.close()
    succounter = succounter + 1
            
print (succounter, "succesfully downloaded")
browser.close()
# Out:
# <module 'ntpath' from 'C:\\Users\\minju\\Anaconda3\\lib\\ntpath.py'>
# Total Count: 1
# Succsessful Count: 0
# URL: https://www.nylonpink.tv/wp-content/uploads/2016/08/Screen-Shot-2016-08-22-at-8.17.21-PM.jpg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-ef2b1b28b7b6> in <module>
#      38
#      39     # 구글 이미지를 읽고 저장한다.
# ---> 40     req = urllib.request(img, headers={'User-Agent': header})
#      41     raw_img = urllib.request.urlopen(req).read()
#      42     File = open(os.path.join("koreanFood" , "koreanFood_" + str(counter) + "." + imgtype), "wb")
#
# TypeError: 'module' object is not callable

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import json
import os
import urllib.request
import argparse
 
searchterm = 'korean+food' # will also be the name of the folder
url = "https://www.google.co.in/search?q="+searchterm+"&source=lnms&tbm=isch"
# NEED TO DOWNLOAD CHROMEDRIVER, insert path to chromedriver inside parentheses in following line
browser = webdriver.Chrome(r'C:\Users\minju\Anaconda3\chromedriver_win32\chromedriver.exe')
browser.get(url)
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
counter = 0
succounter = 0
 
if not os.path.exists(searchterm):
    os.mkdir(searchterm)
 
for _ in range(500):
    browser.execute_script("window.scrollBy(0,10000)")
 
for x in browser.find_elements_by_xpath('//div[contains(@class,"rg_meta")]'):
    counter = counter + 1
    print ("Total Count:", counter)
    print ("Succsessful Count:", succounter)
    print ("URL:",json.loads(x.get_attribute('innerHTML'))["ou"])
 
    img = json.loads(x.get_attribute('innerHTML'))["ou"]
    imgtype = json.loads(x.get_attribute('innerHTML'))["ity"]
    
    req = urllib.request.urlretrieve(img, searchterm)
    raw_img = urllib.request.urlopen(req).read()
    File = open(os.path.join(searchterm , searchterm + "_" + str(counter) + "." + imgtype), "wb")
    File.write(raw_img)
    File.close()
    succounter = succounter + 1
 
print (succounter, "pictures succesfully downloaded")
browser.close()
# Out:
# Total Count: 1
# Succsessful Count: 0
# URL: https://www.thespruceeats.com/thmb/nkV_ru6dKEafuCTGOgUBcGsaxMA=/2048x1152/smart/filters:no_upscale()/classic-korean-bibimbap-recipe-2118765_20_preview-5b1ee284ba61770037c8ad38.jpeg
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-46-2e5df7b5ce64> in <module>
#      30     imgtype = json.loads(x.get_attribute('innerHTML'))["ity"]
#      31
# ---> 32     req = urllib.request.urlretrieve(img, searchterm)
#      33     raw_img = urllib.request.urlopen(req).read()
#      34     File = open(os.path.join(searchterm , searchterm + "_" + str(counter) + "." + imgtype), "wb")
#
# ~\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     255         # Handle temporary file setup.
#     256         if filename:
# --> 257             tfp = open(filename, 'wb')
#     258         else:
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import json
import os
import urllib.request

searchterm = 'korean+food'
url = "https://www.google.com/search?q="+searchterm+"&source=lnms&tbm=isch"
browser = webdriver.Chrome(r'C:\Users\minju\Anaconda3\chromedriver_win32\chromedriver.exe')
browser.get(url)

for i in range(30):
    browser.execute_script('window.scrollBy(0,10000)')
    
for idx, el in enumerate(browser.find_elements_by_class_name("rg_ic")):
    el.screenshot(str(idx) + ".png")
    
browser.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-49-64fcb443fdfb> in <module>
#      14
#      15 for idx, el in enumerate(browser.find_elements_by_class_name("rg_ic")):
# ---> 16     el.screenshot(str(idx) + ".png")
#      17
#      18 browser.close()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in screenshot(self, filename)
#     583             warnings.warn("name used for saved screenshot does not match file "
#     584                           "type. It should end with a `.png` extension", UserWarning)
# --> 585         png = self.screenshot_as_png
#     586         try:
#     587             with open(filename, 'wb') as f:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in screenshot_as_png(self)
#     565             element_png = element.screenshot_as_png
#     566         """
# ...

# %% [markdown]
# # 정리하자

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os

searchterm = 'korean+food'
url = "https://www.google.com/search?q="+searchterm+"&source=lnms&tbm=isch"
browser = webdriver.Chrome(r'C:\Users\minju\Anaconda3\chromedriver_win32\chromedriver.exe')
count = 0;
try:
    os.makedirs('./screenshots')
except OSError:
    pass

browser.get(url)
        
for i in range(50):
    browser.execute_script('window.scrollBy(0,10000)')
            
        
for idx, el in enumerate(browser.find_elements_by_xpath("//img[@class='rg_ic rg_i']")):
    el.screenshot(str(idx) + ".png")
    if ++count == 0:
        break
            
browser.close()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import json
import os
import urllib.request
import argparse
 
searchterm = 'korean+food' # will also be the name of the folder
url = "https://www.google.co.in/search?q="+searchterm+"&source=lnms&tbm=isch"
# NEED TO DOWNLOAD CHROMEDRIVER, insert path to chromedriver inside parentheses in following line
browser = webdriver.Chrome(r'C:\Users\minju\Anaconda3\chromedriver_win32\chromedriver.exe')
browser.get(url)
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
counter = 0
succounter = 0
 
if not os.path.exists(searchterm):
    os.mkdir(searchterm)
 
for _ in range(500):
    browser.execute_script("window.scrollBy(0,10000)")
 
for x in browser.find_elements_by_xpath('//div[contains(@class,"rg_meta")]'):
    counter = counter + 1
    print ("Total Count:", counter)
    print ("Succsessful Count:", succounter)
    print ("URL:",json.loads(x.get_attribute('innerHTML'))["ou"])
 
    img = json.loads(x.get_attribute('innerHTML'))["ou"]
    imgtype = json.loads(x.get_attribute('innerHTML'))["ity"]
    try:
        req = urllib2.Request(img, headers={'User-Agent': header})
        raw_img = urllib2.urlopen(req).read()
        File = open(os.path.join(searchterm , searchterm + "_" + str(counter) + "." + imgtype), "wb")
        File.write(raw_img)
        File.close()
        #dir = os.getcwd() + "/searchterm"
        #urllib.request.urlretrieve(img, dir+counter+'.'+imgtype)
        succounter = succounter + 1
    except:
            print ("can't get img")
 
print (succounter, "pictures succesfully downloaded")
browser.close()
# Out:
# Total Count: 1
# Succsessful Count: 0
# URL: https://www.thespruceeats.com/thmb/XEZVp0xryVGGez4bS_v-vBCZc2Q=/735x0/classic-korean-bibimbap-recipe-2118765_20_preview-5b1ee284ba61770037c8ad38.jpeg
# can't get img
# Total Count: 2
# Succsessful Count: 0
# URL: https://www.matchingfoodandwine.com/files/blogattachments/top/korean-pork-dish@2x.jpg
# can't get img
# Total Count: 3
# Succsessful Count: 0
# URL: https://mykoreankitchen.com/wp-content/uploads/2018/12/0.-Bulgogi-Korean-BBQ-Beef.jpg
# can't get img
# Total Count: 4
# Succsessful Count: 0
# URL: https://cdn.cnn.com/cnnnext/dam/assets/181114125847-korean-food-2620003201012137k-kimchi-assortment-full-169.jpg
# can't get img
# Total Count: 5
# Succsessful Count: 0
# URL: https://img.theculturetrip.com/768x432/wp-content/uploads/2015/03/shutterstock_288572099.jpg
# can't get img
# Total Count: 6
# Succsessful Count: 0
# ...
